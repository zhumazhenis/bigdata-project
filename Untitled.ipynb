# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# To split
from sklearn.model_selection import train_test_split

# Scalers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# Classifiers
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier

# Cross validation
from sklearn.model_selection import cross_val_score

# Hyper Parameter Tuning
from sklearn.model_selection import GridSearchCV

# Scoring
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# P-value check
import scipy.stats as stats

# Classification Report
from sklearn.metrics import classification_report

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv('diabetes.csv')

# %% [markdown]
# #### 1) Following columns should be non-zero values, therefore zeros will be replaced by mean.
# 1. Glucose
# 2. BloodPressure
# 3. SkinThickness
# 4. Insulin
# 5. BMI

# %%
def replaceWithMeans(data):
    means = {}
    nonZeroColumns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
    for column in nonZeroColumns:
        count = 0
        s = 0
        for value in data[column]:
            if value != 0:
                count += 1
                s += value
        means[column] = s / count

    # replace with mean
    for k, v in means.items():
        data[k].replace(to_replace=[0], value=means[k], inplace=True)

replaceWithMeans(data)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0       35.00000  155.548223  33.6
# 1            1     85.0           66.0       29.00000  155.548223  26.6
# 2            8    183.0           64.0       29.15342  155.548223  23.3
# 3            1     89.0           66.0       23.00000   94.000000  28.1
# 4            0    137.0           40.0       35.00000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Select best metrics
# Because of our data is slightly unbalanced (about 75%, 25%), we should not choose 'accuracy' metrics. Because, if we classify all samples as 0, then we already get 75% of accuracy, which is not acceptable. So, we choose f1 metrics, which considers precision and recall.

# %%
sns.countplot(x='Outcome', data=data)
plt.show()
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Normal Distribution Test

# %%
trainFeatures, trainOutcome, testFeatures, testOutcome = splitData(data)
stats.normaltest(trainFeatures)
# Out:
# NormaltestResult(statistic=array([ 69.56759584,  32.19173051,  16.6719284 ,  46.65376003,
#        264.95204963, 107.76302556, 377.1926121 ,  17.03238459]), pvalue=array([7.82687691e-16, 1.02247933e-07, 2.39737928e-04, 7.40056249e-11,
#        2.92680264e-58, 3.97700671e-24, 1.24069484e-82, 2.00200279e-04]))

# %%
data.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc35d08afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35d2ff128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35ca52748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc35ce1f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35cb326a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35cd95c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc35cd51240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35d03a828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc35d03a860>]],
#       dtype=object)

# %% [markdown]
# ### Split data

# %%
def splitData(data):
    trainData, testData = train_test_split(data, test_size=0.20, random_state=66, stratify=data['Outcome'])
    featureColumns = ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Insulin', 'SkinThickness']
    outputColumn = 'Outcome'
    trainFeatures = trainData[featureColumns]
    testFeatures = testData[featureColumns]
    trainOutcome = trainData[outputColumn]
    testOutcome = testData[outputColumn]
    
    return trainFeatures, trainOutcome, testFeatures, testOutcome

# %% [markdown]
# ### Scalers: Standard, MinMax, Robust

# %%
# Standard scale
def standardScale(data):
    featureColumns = ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Insulin', 'SkinThickness']
    scaledFeaturesData = StandardScaler().fit_transform(data[featureColumns])
    scaledData = pd.DataFrame(scaledFeaturesData, columns=featureColumns)
    scaledData['Outcome'] = data['Outcome']
    return scaledData

# MinMax scale
def minMaxScale(data):
    featureColumns = ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Insulin', 'SkinThickness']
    scaledFeaturesData = MinMaxScaler().fit_transform(data[featureColumns])
    scaledData = pd.DataFrame(scaledFeaturesData, columns=featureColumns)
    scaledData['Outcome'] = data['Outcome']
    return scaledData

# Robust scale
def robustScale(data):
    featureColumns = ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Insulin', 'SkinThickness']
    scaledFeaturesData = RobustScaler().fit_transform(data[featureColumns])
    scaledData = pd.DataFrame(scaledFeaturesData, columns=featureColumns)
    scaledData['Outcome'] = data['Outcome']
    return scaledData

# %% [markdown]
# ### Scaler Comparison

# %%
def compareScalers(modelMap, data):
    result = {
        'Name': [],
        'Standard': [],
        'MinMax': [],
        'Robust': []
    }
    for name, model in modelsMap.items():
        scoring = make_scorer(f1_score)
        # StandardScaler
        minMaxScaledData = minMaxScale(data)
        trainFeaturesMinMax, trainOutcomeMinMax, testFeaturesMinMax, testOutcomeMinMax = splitData(minMaxScaledData)
        crossValidationResult = cross_val_score(model, trainFeaturesMinMax, trainOutcomeMinMax, cv = 5, scoring = scoring)
        result['Standard'].append(crossValidationResult.mean())
        
        # MinMaxScaler
        minMaxScaledData = minMaxScale(data)
        trainFeaturesMinMax, trainOutcomeMinMax, testFeaturesMinMax, testOutcomeMinMax = splitData(minMaxScaledData)
        crossValidationResult = cross_val_score(model, trainFeaturesMinMax, trainOutcomeMinMax, cv = 5, scoring = scoring)
        result['MinMax'].append(crossValidationResult.mean())
        
        # RobustScaler
        robustScaledData = robustScale(data)
        trainFeaturesRobust, trainOutcomeRobust, testFeaturesRobust, testOutcomeRobust = splitData(robustScaledData)
        crossValidationResult = cross_val_score(model, trainFeaturesRobust, trainOutcomeRobust, cv = 5, scoring = scoring)
        result['Robust'].append(crossValidationResult.mean())
    
        result['Name'].append(name)        
    scalerComparison = pd.DataFrame(result)
    return scalerComparison

modelsMap = {
    'Linear Svm': svm.SVC(kernel='linear', class_weight = 'balanced'), 
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Decision Trees': DecisionTreeClassifier(),
    'Gaussian Naive Bayes': GaussianNB(), 
    'GradientBoosting': GradientBoostingClassifier(random_state=66),
    'KNeighborsClassifier': KNeighborsClassifier()
}

comparison = compareScalers(modelsMap, data)
comparison


data = standardScale(data)
clf = RandomForestClassifier(max_depth=4, n_estimators=10)

xTrain, yTrain, xTest, yTest = splitData(data)
# featureColumns = ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Insulin', 'SkinThickness']
featureColumns = ['Glucose', 'BMI', 'DiabetesPedigreeFunction', 'Age']
xTrain = xTrain[featureColumns]
xTest = xTest[featureColumns]

clf = clf.fit(xTrain, yTrain)
yPred = clf.predict(xTest)
print(classification_report(yTest, yPred))
print(confusion_matrix(yTest, yPred))




knn_clf = RandomForestClassifier()

params = {
    'n_estimators': np.arange(1,30),
    'max_depth': np.arange(1,7)
}
      
grid = GridSearchCV(estimator=knn_clf, param_grid=params, cv=5, scoring=make_scorer(f1_score))

grid.fit(xTrain,yTrain)

print("Best Score:" + str(grid.best_score_))
print("Best Parameters: " + str(grid.best_params_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       100
#            1       0.69      0.74      0.71        54
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.78      0.78       154
# weighted avg       0.80      0.79      0.79       154
#
# [[82 18]
#  [14 40]]
# Best Score:0.6549883307081104
# Best Parameters: {'max_depth': 5, 'n_estimators': 23}

# %%
yTest.shape
# Out:
# (154,)

# %% [markdown]
# ### Select Standard Scaler

# %%
data = standardScale(data)

# %% [markdown]
# ### Hyper Parameter Tuning

# %% [markdown]
# ### P-value

# %%
trainFeatures, trainOutcome, testFeatures, testOutcome = splitData(data)
stats.normaltest(trainFeatures)
# Out:
# NormaltestResult(statistic=array([ 69.56759584,  32.19173051,  16.6719284 ,  46.65376003,
#        264.95204963, 107.76302556, 377.1926121 ,  17.03238459]), pvalue=array([7.82687691e-16, 1.02247933e-07, 2.39737928e-04, 7.40056249e-11,
#        2.92680264e-58, 3.97700671e-24, 1.24069484e-82, 2.00200279e-04]))

# %% [markdown]
# ### 2) Age column will divied into three categorical columns Young, Middle, Old

# %%
uniqueAges = data['Age'].unique()
uniqueAges.sort()

def findAgePivots():
    n = len(uniqueAges)
    result = [[0] * n] * n
    for i in range(n):
        for j in range(i + 1, n):
            age1 = uniqueAges[i]
            age2 = uniqueAges[j]
            data[data['Age'] <= age1]['Outcome'].value_counts().
# Out:
#   File "<ipython-input-78-ba0db5843b1d>", line 11
#     data[data['Age'] <= age1]['Outcome'].value_counts().
#                                                         ^
# SyntaxError: invalid syntax

# %%
for x, y in data[data['Age'] <= 21]['Outcome'].value_counts().items():
    print(x, y)

# %%
data[data['Age'] <= 21].groupby('Outcome').count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                 58       58             58             58       58   58
# 1                  5        5              5              5        5    5
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                              58   58
# 1                               5    5

# %% [markdown]
# ### 3) Pregnancies column will be divied into three categorical columns Small, Medium, Large

# %%
data[data['Age'] == 21].
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 3              1     89.0      66.000000       23.00000   94.000000
# 55             1     73.0      50.000000       10.00000  155.548223
# 60             2     84.0      72.405184       29.15342  155.548223
# 90             1     80.0      55.000000       29.15342  155.548223
# 94             2    142.0      82.000000       18.00000   64.000000
# ..           ...      ...            ...            ...         ...
# 671            1     99.0      58.000000       10.00000  155.548223
# 713          500    134.0      58.000000       20.00000  291.000000
# 721            1    114.0      66.000000       36.00000  200.000000
# 736          500    126.0      86.000000       27.00000  120.000000
# 738            2     99.0      60.000000       17.00000  160.000000
#
#            BMI  DiabetesPedigreeFunction  Age  Outcome
# 3    28.100000                     0.167   21        0
# 55   23.000000                     0.248   21        0
# 60   32.457464                     0.304   21        0
# 90   19.100000                     0.258   21        0
# 94   24.700000                     0.761   21        0
# ..         ...                       ...  ...      ...
# 671  25.400000                     0.551   21        0
# 713  26.400000                     0.352   21        0
# 721  38.100000                     0.289   21        0
# 736  27.400000                     0.515   21        0
# 738  36.600000                     0.453   21        0
#
# [63 rows x 9 columns]

# %%
data['Pregnancies'].replace(to_replace=[0], value=500, inplace=True)
# count values
data.groupby('Pregnancies').count()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Pregnancies
# 1                135            135            135      135  135
# 2                103            103            103      103  103
# 3                 75             75             75       75   75
# 4                 68             68             68       68   68
# 5                 57             57             57       57   57
# 6                 50             50             50       50   50
# 7                 45             45             45       45   45
# 8                 38             38             38       38   38
# 9                 28             28             28       28   28
# 10                24             24             24       24   24
# 11                11             11             11       11   11
# 12                 9              9              9        9    9
# 13                10             10             10       10   10
# 14                 2              2              2        2    2
# 15                 1              1              1        1    1
# 17                 1              1              1        1    1
# 500              111            111            111      111  111
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 1                                 135  135      135
# 2                                 103  103      103
# 3                                  75   75       75
# 4                                  68   68       68
# 5                                  57   57       57
# 6                                  50   50       50
# 7                                  45   45       45
# 8                                  38   38       38
# 9                                  28   28       28
# 10                                 24   24       24
# 11                                 11   11       11
# 12                                  9    9        9
# 13                                 10   10       10
# 14                                  2    2        2
# 15                                  1    1        1
# 17                                  1    1        1
# 500                               111  111      111

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0       35.00000  155.548223  33.6
# 1            1     85.0           66.0       29.00000  155.548223  26.6
# 2            8    183.0           64.0       29.15342  155.548223  23.3
# 3            1     89.0           66.0       23.00000   94.000000  28.1
# 4            0    137.0           40.0       35.00000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %% [markdown]
# ### Nature of the dataset
#
#
#
# 2) Feature extraction.
# 1. Number of pregnancies should be categorical or continuous?
# 2. Consider pregnancy and age relationship.
# 3. Consider feature importances (using forest).
# 4. Correlation matrix.
# 5. Check p-values for normal distribution.
#
#
# 3) Error estimation and model selection.
# 1. Hold out.
# 2. Cross validation.
# 3. Leave one out.
# 4. Bootstrap.
# 5. Hyperparameter tuning for KNN classifier.

# %% [markdown]
# ### Useful approaches
# 1. Classify using multiple models votes.
# 2.
#
# ### Suggestions
# 1. Use prior probabilites in order to prevent classifying diabetes as not diabet

# %%
dataCopy = data.copy(deep = True)
dataCopy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = dataCopy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(value=np.NaN, to_replace=0)

## showing the count of Nans
print(dataCopy.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
dataCopy

# %%
p = data.hist(figsize = (20,20))

# %%
dataCopy.isnull().sum()
dataCopy.isin([0]).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64
